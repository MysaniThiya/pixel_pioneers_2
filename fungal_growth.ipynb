# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# Define paths
input_folder = 'contour_detected_images'  # Replace with the path to your flood filled images

# Initialize a list to store the areas
areas = []

# Process each image in the input folder
for filename in sorted(os.listdir(input_folder)):
    if filename.endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
        # Load the image
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        # Calculate the area of the fungal growth by counting zero (black) pixels
        area = image.size - cv2.countNonZero(image)
        areas.append(area)

        print(f'Processed {filename}: Area = {area}')

# Generate a time array based on the number of images
time = list(range(1, len(areas) + 1))  # Assuming each image represents a day

# Plot the growth rate
plt.figure(figsize=(10, 6))
plt.plot(time, areas, marker='o', linestyle='-', color='b')
plt.title('Fungal Growth Rate Over Time')
plt.xlabel('Time (Days)')
plt.ylabel('Fungal Growth Area (Pixels)')
plt.grid(True)
plt.savefig('fungal_growth_rate.png')  # Save the plot as an image
plt.show()
# Out:
# Processed flood_filled_adjusted_gray_Day_01.jpg: Area = 9732
# Processed flood_filled_adjusted_gray_Day_02.jpg: Area = 8109
# Processed flood_filled_adjusted_gray_Day_03.jpg: Area = 4613
# Processed flood_filled_adjusted_gray_Day_04.jpg: Area = 17943
# Processed flood_filled_adjusted_gray_Day_05.jpg: Area = 38698
# Processed flood_filled_adjusted_gray_Day_06.jpg: Area = 60981
# Processed flood_filled_adjusted_gray_Day_07.jpg: Area = 102683
# Processed flood_filled_adjusted_gray_Day_08.jpg: Area = 162437
# Processed flood_filled_adjusted_gray_Day_09.jpg: Area = 198204
# Processed flood_filled_adjusted_gray_Day_10.jpg: Area = 139600
# Processed flood_filled_adjusted_gray_Day_11.jpg: Area = 194486
# Processed flood_filled_adjusted_gray_Day_12.jpg: Area = 82039
# Processed flood_filled_adjusted_gray_Day_13.jpg: Area = 196688
# Processed flood_filled_adjusted_gray_Day_14.jpg: Area = 132587
